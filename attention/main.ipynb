# %%
# GOAL: Attention Mechanism from Scratch
# - Implement Self-Attention
# - Compare to LSTM memory (You have to Implement LSTM first)
# - Visualize Attention Weights
# - Reference "Attention Is All You Need"
